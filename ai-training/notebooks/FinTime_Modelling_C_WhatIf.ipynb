# %%
# !pip install tensorflow tensorflowjs -q

# %%
# =========================================================
# IMPORT LIBRARY
# =========================================================
import pandas as pd
import numpy as np
import os
import json
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflowjs as tfjs

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from google.colab import files

# Set seed untuk reproducibility
tf.random.set_seed(42)
np.random.seed(42)

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %%
# =========================================================
# LOAD DATA & PREPROCESSING
# =========================================================
df = pd.read_csv("/content/dataset_c_whatif.csv")

print(f"Shape awal: {df.shape}")
print(f"\nDistribusi label:")
print(df['label_whatif'].value_counts())

# Hapus kolom yang menyebabkan data leakage
FORBIDDEN_COLS = ["etr_after_purchase", "cashflow_after_purchase",
                  "months_to_recover", "current_etr_trend"]
df = df.drop(columns=[c for c in FORBIDDEN_COLS if c in df.columns], errors='ignore')

# Pisahkan Fitur & Label
X = df.drop(columns=["label_whatif", "persona_id"], errors='ignore')
y = df["label_whatif"]

# One-Hot Encoding untuk kolom kategorikal
X = pd.get_dummies(X, drop_first=False)
final_feature_columns = X.columns.tolist()
print(f"\nJumlah fitur setelah encoding: {len(final_feature_columns)}")

# Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Encode label
le = LabelEncoder()
y_encoded = le.fit_transform(y)
class_names = le.classes_.tolist()
print(f"Kelas: {class_names}")

# Stratified Split - menjaga proporsi kelas di train & test
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

print(f"\nDistribusi kelas di Train set: {dict(zip(class_names, np.bincount(y_train)))}")
print(f"Distribusi kelas di Test set:  {dict(zip(class_names, np.bincount(y_test)))}")
# Out:
# Shape awal: (10000, 28)
#
# Distribusi label:
# label_whatif
# just_buy       7364
# buy_careful    1953
# dont_buy        683
# Name: count, dtype: int64
#
# Jumlah fitur setelah encoding: 38
# Kelas: ['buy_careful', 'dont_buy', 'just_buy']
#
# Distribusi kelas di Train set: {'buy_careful': np.int64(1563), 'dont_buy': np.int64(546), 'just_buy': np.int64(5891)}
# Distribusi kelas di Test set:  {'buy_careful': np.int64(390), 'dont_buy': np.int64(137), 'just_buy': np.int64(1473)}

# %%
# =========================================================
# PERSIAPAN LABEL & BOBOT KELAS
# =========================================================
y_train_ohe = tf.keras.utils.to_categorical(y_train)
y_test_ohe  = tf.keras.utils.to_categorical(y_test)

# Hitung class weight secara otomatis berdasarkan distribusi data
cw_values = compute_class_weight('balanced', classes=np.unique(y_encoded), y=y_train)
balanced_weights = {i: float(w) for i, w in enumerate(cw_values)}

print("Class weights yang dihitung secara otomatis:")
for i, name in enumerate(class_names):
    print(f"  {i} ({name}): {balanced_weights[i]:.4f}")
# Out:
# Class weights yang dihitung secara otomatis:
#   0 (buy_careful): 1.7061
#   1 (dont_buy): 4.8840
#   2 (just_buy): 0.4527

# %%
# =========================================================
# ARSITEKTUR MODEL - REGULARIZED RESIDUAL NETWORK
# =========================================================

n_features = X_train.shape[1]
n_classes = len(class_names)
L2 = 1e-3  # Regularization strength

inputs = tf.keras.layers.Input(shape=(n_features,))

# --- Block 1: Proyeksi Awal ---
x = tf.keras.layers.Dense(64, kernel_regularizer=tf.keras.regularizers.l2(L2))(inputs)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(0.30)(x)  # Dropout ditingkatkan ke 30%

# --- Residual Block ---
res = x
x = tf.keras.layers.Dense(64, kernel_regularizer=tf.keras.regularizers.l2(L2))(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(0.30)(x)
x = tf.keras.layers.Add()([x, res])  # Skip connection

# --- Block 2: Penyempitan ---
x = tf.keras.layers.Dense(32, kernel_regularizer=tf.keras.regularizers.l2(L2))(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(0.20)(x)

# --- Output ---
outputs = tf.keras.layers.Dense(n_classes, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),  # LR diturunkan
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 38)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 64)        │      2,496 │ input_layer_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_30[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 64)        │          0 │ activation_7[0][… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 64)        │      4,160 │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_31[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 64)        │          0 │ activation_8[0][… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64)        │          0 │ dropout_15[0][0], │
# │                     │                   │            │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 32)        │      2,080 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_32[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 32)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 32)        │          0 │ activation_9[0][… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 3)         │         99 │ dropout_16[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,475 (37.01 KB)
#  Trainable params: 9,155 (35.76 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
# =========================================================
# TRAINING DENGAN CALLBACKS
# =========================================================
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-5,
    verbose=1
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

print("\nMemulai Training...")
history = model.fit(
    X_train, y_train_ohe,
    epochs=150,
    batch_size=64,
    validation_data=(X_test, y_test_ohe),
    class_weight=balanced_weights,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Memulai Training...
# Epoch 1/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4066 - loss: 1.3315 - val_accuracy: 0.5695 - val_loss: 1.0999 - learning_rate: 5.0000e-04
# Epoch 2/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5968 - loss: 1.0354 - val_accuracy: 0.7610 - val_loss: 0.8604 - learning_rate: 5.0000e-04
# Epoch 3/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6889 - loss: 0.9076 - val_accuracy: 0.7970 - val_loss: 0.7414 - learning_rate: 5.0000e-04
# Epoch 4/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7416 - loss: 0.8208 - val_accuracy: 0.8220 - val_loss: 0.6691 - learning_rate: 5.0000e-04
# Epoch 5/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7615 - loss: 0.7755 - val_accuracy: 0.8385 - val_loss: 0.6234 - learning_rate: 5.0000e-04
# Epoch 6/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7845 - loss: 0.7325 - val_accuracy: 0.8490 - val_loss: 0.5896 - learning_rate: 5.0000e-04
# Epoch 7/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7980 - loss: 0.7123 - val_accuracy: 0.8555 - val_loss: 0.5591 - learning_rate: 5.0000e-04
# Epoch 8/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8076 - loss: 0.6804 - val_accuracy: 0.8610 - val_loss: 0.5471 - learning_rate: 5.0000e-04
# Epoch 9/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8154 - loss: 0.6757 - val_accuracy: 0.8650 - val_loss: 0.5357 - learning_rate: 5.0000e-04
# Epoch 10/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8216 - loss: 0.6457 - val_accuracy: 0.8635 - val_loss: 0.5253 - learning_rate: 5.0000e-04
# Epoch 11/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8289 - loss: 0.6318 - val_accuracy: 0.8710 - val_loss: 0.5042 - learning_rate: 5.0000e-04
# Epoch 12/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8284 - loss: 0.6261 - val_accuracy: 0.8720 - val_loss: 0.4980 - learning_rate: 5.0000e-04
# Epoch 13/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8342 - loss: 0.6181 - val_accuracy: 0.8710 - val_loss: 0.4934 - learning_rate: 5.0000e-04
# Epoch 14/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8307 - loss: 0.6126 - val_accuracy: 0.8765 - val_loss: 0.4894 - learning_rate: 5.0000e-04
# Epoch 15/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8418 - loss: 0.5876 - val_accuracy: 0.8750 - val_loss: 0.4762 - learning_rate: 5.0000e-04
# Epoch 16/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8401 - loss: 0.5873 - val_accuracy: 0.8795 - val_loss: 0.4600 - learning_rate: 5.0000e-04
# Epoch 17/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8425 - loss: 0.5751 - val_accuracy: 0.8810 - val_loss: 0.4650 - learning_rate: 5.0000e-04
# Epoch 18/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8469 - loss: 0.5677 - val_accuracy: 0.8770 - val_loss: 0.4642 - learning_rate: 5.0000e-04
# Epoch 19/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8576 - loss: 0.5477 - val_accuracy: 0.8795 - val_loss: 0.4563 - learning_rate: 5.0000e-04
# Epoch 20/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8486 - loss: 0.5543 - val_accuracy: 0.8820 - val_loss: 0.4556 - learning_rate: 5.0000e-04
# Epoch 21/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8541 - loss: 0.5412 - val_accuracy: 0.8850 - val_loss: 0.4475 - learning_rate: 5.0000e-04
# Epoch 22/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8501 - loss: 0.5372 - val_accuracy: 0.8830 - val_loss: 0.4413 - learning_rate: 5.0000e-04
# Epoch 23/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8587 - loss: 0.5341 - val_accuracy: 0.8875 - val_loss: 0.4328 - learning_rate: 5.0000e-04
# Epoch 24/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8522 - loss: 0.5411 - val_accuracy: 0.8875 - val_loss: 0.4322 - learning_rate: 5.0000e-04
# Epoch 25/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8608 - loss: 0.5267 - val_accuracy: 0.8865 - val_loss: 0.4315 - learning_rate: 5.0000e-04
# Epoch 26/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8547 - loss: 0.5212 - val_accuracy: 0.8890 - val_loss: 0.4229 - learning_rate: 5.0000e-04
# Epoch 27/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8596 - loss: 0.5141 - val_accuracy: 0.8865 - val_loss: 0.4275 - learning_rate: 5.0000e-04
# Epoch 28/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8639 - loss: 0.5080 - val_accuracy: 0.8855 - val_loss: 0.4276 - learning_rate: 5.0000e-04
# Epoch 29/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8622 - loss: 0.5030 - val_accuracy: 0.8845 - val_loss: 0.4198 - learning_rate: 5.0000e-04
# Epoch 30/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8601 - loss: 0.4965 - val_accuracy: 0.8860 - val_loss: 0.4176 - learning_rate: 5.0000e-04
# Epoch 31/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8651 - loss: 0.4954 - val_accuracy: 0.8940 - val_loss: 0.4132 - learning_rate: 5.0000e-04
# Epoch 32/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8610 - loss: 0.4822 - val_accuracy: 0.8915 - val_loss: 0.4120 - learning_rate: 5.0000e-04
# Epoch 33/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8674 - loss: 0.4796 - val_accuracy: 0.8900 - val_loss: 0.4126 - learning_rate: 5.0000e-04
# Epoch 34/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8690 - loss: 0.4797 - val_accuracy: 0.8930 - val_loss: 0.4033 - learning_rate: 5.0000e-04
# Epoch 35/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8708 - loss: 0.4770 - val_accuracy: 0.8865 - val_loss: 0.4127 - learning_rate: 5.0000e-04
# Epoch 36/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8686 - loss: 0.4733 - val_accuracy: 0.8900 - val_loss: 0.4057 - learning_rate: 5.0000e-04
# Epoch 37/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8739 - loss: 0.4607 - val_accuracy: 0.8890 - val_loss: 0.4056 - learning_rate: 5.0000e-04
# Epoch 38/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8730 - loss: 0.4594 - val_accuracy: 0.8915 - val_loss: 0.4035 - learning_rate: 5.0000e-04
# Epoch 39/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8746 - loss: 0.4567 - val_accuracy: 0.8980 - val_loss: 0.3977 - learning_rate: 5.0000e-04
# Epoch 40/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8699 - loss: 0.4580 - val_accuracy: 0.8975 - val_loss: 0.3930 - learning_rate: 5.0000e-04
# Epoch 41/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8734 - loss: 0.4464 - val_accuracy: 0.8910 - val_loss: 0.4004 - learning_rate: 5.0000e-04
# Epoch 42/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.4510 - val_accuracy: 0.8915 - val_loss: 0.3974 - learning_rate: 5.0000e-04
# Epoch 43/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8781 - loss: 0.4401 - val_accuracy: 0.8985 - val_loss: 0.3894 - learning_rate: 5.0000e-04
# Epoch 44/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8726 - loss: 0.4352 - val_accuracy: 0.8920 - val_loss: 0.3938 - learning_rate: 5.0000e-04
# Epoch 45/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8737 - loss: 0.4316 - val_accuracy: 0.8925 - val_loss: 0.3898 - learning_rate: 5.0000e-04
# Epoch 46/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8767 - loss: 0.4254 - val_accuracy: 0.8960 - val_loss: 0.3794 - learning_rate: 5.0000e-04
# Epoch 47/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8752 - loss: 0.4255 - val_accuracy: 0.8930 - val_loss: 0.3878 - learning_rate: 5.0000e-04
# Epoch 48/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8741 - loss: 0.4323 - val_accuracy: 0.8935 - val_loss: 0.3854 - learning_rate: 5.0000e-04
# Epoch 49/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8773 - loss: 0.4194 - val_accuracy: 0.8935 - val_loss: 0.3868 - learning_rate: 5.0000e-04
# Epoch 50/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8808 - loss: 0.4136 - val_accuracy: 0.8925 - val_loss: 0.3871 - learning_rate: 5.0000e-04
# Epoch 51/150
# 108/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8796 - loss: 0.4173
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8766 - loss: 0.4157 - val_accuracy: 0.8890 - val_loss: 0.3934 - learning_rate: 5.0000e-04
# Epoch 52/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8770 - loss: 0.4067 - val_accuracy: 0.8950 - val_loss: 0.3843 - learning_rate: 2.5000e-04
# Epoch 53/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8776 - loss: 0.4068 - val_accuracy: 0.8920 - val_loss: 0.3857 - learning_rate: 2.5000e-04
# Epoch 54/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8823 - loss: 0.3987 - val_accuracy: 0.8985 - val_loss: 0.3799 - learning_rate: 2.5000e-04
# Epoch 55/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8861 - loss: 0.4021 - val_accuracy: 0.8950 - val_loss: 0.3818 - learning_rate: 2.5000e-04
# Epoch 56/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8840 - loss: 0.3983 - val_accuracy: 0.8955 - val_loss: 0.3793 - learning_rate: 2.5000e-04
# Epoch 57/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8811 - loss: 0.3964 - val_accuracy: 0.8940 - val_loss: 0.3838 - learning_rate: 2.5000e-04
# Epoch 58/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8844 - loss: 0.3943 - val_accuracy: 0.8955 - val_loss: 0.3782 - learning_rate: 2.5000e-04
# Epoch 59/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8817 - loss: 0.3946 - val_accuracy: 0.8955 - val_loss: 0.3804 - learning_rate: 2.5000e-04
# Epoch 60/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8856 - loss: 0.3988 - val_accuracy: 0.8965 - val_loss: 0.3803 - learning_rate: 2.5000e-04
# Epoch 61/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8824 - loss: 0.3915 - val_accuracy: 0.8955 - val_loss: 0.3791 - learning_rate: 2.5000e-04
# Epoch 62/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8882 - loss: 0.3817 - val_accuracy: 0.8955 - val_loss: 0.3786 - learning_rate: 2.5000e-04
# Epoch 63/150
# 111/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8816 - loss: 0.3950
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8841 - loss: 0.3834 - val_accuracy: 0.8970 - val_loss: 0.3802 - learning_rate: 2.5000e-04
# Epoch 64/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8923 - loss: 0.3849 - val_accuracy: 0.8970 - val_loss: 0.3752 - learning_rate: 1.2500e-04
# Epoch 65/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8840 - loss: 0.3973 - val_accuracy: 0.8970 - val_loss: 0.3761 - learning_rate: 1.2500e-04
# Epoch 66/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8874 - loss: 0.3857 - val_accuracy: 0.8990 - val_loss: 0.3750 - learning_rate: 1.2500e-04
# Epoch 67/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8880 - loss: 0.3860 - val_accuracy: 0.8985 - val_loss: 0.3750 - learning_rate: 1.2500e-04
# Epoch 68/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8881 - loss: 0.3800 - val_accuracy: 0.8965 - val_loss: 0.3794 - learning_rate: 1.2500e-04
# Epoch 69/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8892 - loss: 0.3816 - val_accuracy: 0.8975 - val_loss: 0.3798 - learning_rate: 1.2500e-04
# Epoch 70/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8911 - loss: 0.3789 - val_accuracy: 0.8965 - val_loss: 0.3761 - learning_rate: 1.2500e-04
# Epoch 71/150
# 110/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8882 - loss: 0.3957
# Epoch 71: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8880 - loss: 0.3843 - val_accuracy: 0.8975 - val_loss: 0.3774 - learning_rate: 1.2500e-04
# Epoch 72/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8932 - loss: 0.3751 - val_accuracy: 0.8960 - val_loss: 0.3777 - learning_rate: 6.2500e-05
# Epoch 73/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8884 - loss: 0.3815 - val_accuracy: 0.8965 - val_loss: 0.3763 - learning_rate: 6.2500e-05
# Epoch 74/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8885 - loss: 0.3765 - val_accuracy: 0.8980 - val_loss: 0.3735 - learning_rate: 6.2500e-05
# Epoch 75/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8857 - loss: 0.3849 - val_accuracy: 0.8970 - val_loss: 0.3758 - learning_rate: 6.2500e-05
# Epoch 76/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8865 - loss: 0.3797 - val_accuracy: 0.8955 - val_loss: 0.3765 - learning_rate: 6.2500e-05
# Epoch 77/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8850 - loss: 0.3796 - val_accuracy: 0.8955 - val_loss: 0.3766 - learning_rate: 6.2500e-05
# Epoch 78/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8888 - loss: 0.3794 - val_accuracy: 0.8980 - val_loss: 0.3754 - learning_rate: 6.2500e-05
# Epoch 79/150
# 110/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8823 - loss: 0.3872
# Epoch 79: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8855 - loss: 0.3789 - val_accuracy: 0.8985 - val_loss: 0.3754 - learning_rate: 6.2500e-05
# Epoch 80/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8909 - loss: 0.3683 - val_accuracy: 0.8990 - val_loss: 0.3753 - learning_rate: 3.1250e-05
# Epoch 81/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8891 - loss: 0.3715 - val_accuracy: 0.8990 - val_loss: 0.3757 - learning_rate: 3.1250e-05
# Epoch 82/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8909 - loss: 0.3704 - val_accuracy: 0.8985 - val_loss: 0.3745 - learning_rate: 3.1250e-05
# Epoch 83/150
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8906 - loss: 0.3731 - val_accuracy: 0.8970 - val_loss: 0.3750 - learning_rate: 3.1250e-05
# Epoch 84/150
# 111/125 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8868 - loss: 0.3900
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8894 - loss: 0.3716 - val_accuracy: 0.8960 - val_loss: 0.3766 - learning_rate: 3.1250e-05
# Epoch 84: early stopping
# Restoring model weights from the end of the best epoch: 74.

# %%
# =========================================================
# VISUALISASI & EVALUASI
# =========================================================
fig, ax = plt.subplots(1, 2, figsize=(14, 5))

# Akurasi
ax[0].plot(history.history['accuracy'], label='Train Accuracy', color='royalblue')
ax[0].plot(history.history['val_accuracy'], label='Val Accuracy', color='orange')
ax[0].set_title('Accuracy per Epoch')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend()
ax[0].grid(True, alpha=0.3)

# Loss
ax[1].plot(history.history['loss'], label='Train Loss', color='royalblue')
ax[1].plot(history.history['val_loss'], label='Val Loss', color='orange')
ax[1].set_title('Loss per Epoch')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend()
ax[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# --- Evaluasi Metrik ---
y_pred_probs   = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)

train_acc = history.history['accuracy'][-1]
val_acc   = history.history['val_accuracy'][-1]
print(f"\nTrain Accuracy : {train_acc:.4f}")
print(f"Val Accuracy   : {val_acc:.4f}")
print(f"Overfitting Gap: {train_acc - val_acc:.4f}  (target < 0.03)")
print(f"Epochs berjalan: {len(history.history['accuracy'])}")

print("\n" + "="*50)
print("CLASSIFICATION REPORT")
print("="*50)
print(classification_report(y_test, y_pred_classes, target_names=class_names))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# Train Accuracy : 0.8894
# Val Accuracy   : 0.8960
# Overfitting Gap: -0.0066  (target < 0.03)
# Epochs berjalan: 84
#
# ==================================================
# CLASSIFICATION REPORT
# ==================================================
#               precision    recall  f1-score   support
#
#  buy_careful       0.75      0.73      0.74       390
#     dont_buy       0.81      0.93      0.87       137
#     just_buy       0.95      0.94      0.94      1473
#
#     accuracy                           0.90      2000
#    macro avg       0.84      0.87      0.85      2000
# weighted avg       0.90      0.90      0.90      2000

# %%
# =========================================================
# EXPORT MODEL & METADATA
# =========================================================
tfjs_path = "tfjs_model_whatif"
tfjs.converters.save_keras_model(model, tfjs_path)

metadata = {
    "feature_columns": final_feature_columns,
    "class_names": class_names,
    "scaler_mean": scaler.mean_.tolist(),
    "scaler_variance": scaler.var_.tolist(),
    "scaler_scale": scaler.scale_.tolist()
}

with open(f"{tfjs_path}/metadata.json", "w") as f:
    json.dump(metadata, f)

print(f"Model disimpan ke: {tfjs_path}/")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# failed to lookup keras version from the file,
#     this is likely a weight only file
# Model disimpan ke: tfjs_model_whatif/

# %%
# =========================================================
# DOWNLOAD
# =========================================================
# !zip -r model_whatif_tfjs.zip {tfjs_path}
files.download("model_whatif_tfjs.zip")
print("\nSelesai!")
# Out:
#   adding: tfjs_model_whatif/ (stored 0%)
#   adding: tfjs_model_whatif/metadata.json (deflated 53%)
#   adding: tfjs_model_whatif/model.json (deflated 89%)
#   adding: tfjs_model_whatif/group1-shard1of1.bin (deflated 7%)
# Selesai!
